# %%
# %matplotlib inline
import numpy as np
import h5py
import matplotlib.pyplot as plt

# %%
h5f = h5py.File('/home/ubuntu/data/melbourne-university-seizure-prediction/data.hdf5', 'r')

# %%
data = h5f['train'][0][:, 0]
data = data.reshape((24, -1))
plt.plot(data.var(axis=1))

# %%
data = h5f['train'][0][:, 1]
data = data.reshape((24, -1))
plt.plot(data.var(axis=1))

# %%
data = h5f['train'][0][:, 2]
data = data.reshape((24, -1))
plt.plot(data.var(axis=1))

# %%
h5f['train_labels'][()][0]
# Out:
# array([b'/home/ubun'],
#       dtype='|S10')
