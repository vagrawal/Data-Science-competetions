# %%
import numpy as np
np.random.seed(2016)
import os
import glob
import cv2
import datetime
import time
from sklearn.cross_validation import KFold
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten, MaxoutDense
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.optimizers import Adam
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping, RemoteMonitor, ModelCheckpoint
from keras.utils import np_utils
from keras.regularizers import l2
from sklearn.metrics import log_loss
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using Theano backend.
# WARNING (theano.gof.compilelock): Overriding existing lock by dead process '6339' (I am process '10370')
# Using gpu device 0: GRID K520 (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 5005)

# %%
img_rows, img_cols = 64, 64
nfolds = 5

def get_im_cv2(path, img_rows, img_cols):
    img = cv2.imread(path, 0)
    resized = cv2.resize(img, (img_cols, img_rows), cv2.INTER_LINEAR)
    return resized


def load_train(img_rows, img_cols):
    X_train = []
    X_train_id = []
    mask_train = []
    start_time = time.time()

    print('Read train images')
    files = glob.glob("train/*[0-9].tif")
    for fl in files:
        flbase = os.path.basename(fl)
        img = get_im_cv2(fl, img_rows, img_cols)
        X_train.append(img)
        X_train_id.append(flbase[:-4])
        mask_path = "train/" + flbase[:-4] + "_mask.tif"
        mask = get_im_cv2(mask_path, img_rows, img_cols)
        mask_train.append(mask)

    print('Read train data time: {} seconds'.format(round(time.time() - start_time, 2)))
    return X_train, mask_train, X_train_id


def load_test(img_rows, img_cols):
    print('Read test images')
    files = glob.glob("test/*[0-9].tif")
    X_test = []
    X_test_id = []
    total = 0
    start_time = time.time()
    for fl in files:
        flbase = os.path.basename(fl)
        img = get_im_cv2(fl, img_rows, img_cols)
        X_test.append(img)
        X_test_id.append(flbase[:-4])
        total += 1

    print('Read test data time: {} seconds'.format(round(time.time() - start_time, 2)))
    return X_test, X_test_id


def rle_encode(img, order='F'):
    bytes = img.reshape(img.shape[0] * img.shape[1], order=order)
    runs = []
    r = 0
    pos = 1
    for c in bytes:
        if c == 0:
            if r != 0:
                runs.append((pos, r))
                pos += r
                r = 0
            pos += 1
        else:
            r += 1

    if r != 0:
        runs.append((pos, r))
        pos += r

    z = ''
    for rr in runs:
        z += str(rr[0]) + ' ' + str(rr[1]) + ' '
    return z[:-1]


def find_best_mask():
    files = glob.glob(os.path.join("train", "*_mask.tif"))
    overall_mask = cv2.imread(files[0], cv2.IMREAD_GRAYSCALE)
    overall_mask.fill(0)
    overall_mask = overall_mask.astype(np.float32)

    for fl in files:
        mask = cv2.imread(fl, cv2.IMREAD_GRAYSCALE)
        overall_mask += mask
    overall_mask /= 255
    max_value = overall_mask.max()
    koeff = 0.5
    overall_mask[overall_mask < koeff * max_value] = 0
    overall_mask[overall_mask >= koeff * max_value] = 255
    overall_mask = overall_mask.astype(np.uint8)
    return overall_mask


def create_submission(predictions, test_id, info):
    sub_file = os.path.join('submission_' + info + '_' + str(datetime.datetime.now().strftime("%Y-%m-%d-%H-%M")) + '.csv')
    subm = open(sub_file, "w")
    mask = find_best_mask()
    encode = rle_encode(mask)
    subm.write("img,pixels\n")
    for i in range(len(test_id)):
        subm.write(str(test_id[i]) + ',')
        if predictions[i][1] > 0.5:
            subm.write(encode)
        subm.write('\n')
    subm.close()


def get_empty_mask_state(mask):
    out = []
    for i in range(len(mask)):
        if mask[i].sum() == 0:
            out.append(0)
        else:
            out.append(1)
    return np.array(out)


def read_and_normalize_train_data(img_rows, img_cols):
    train_data, train_target, train_id = load_train(img_rows, img_cols)
    train_data = np.array(train_data, dtype=np.uint8)
    train_target = np.array(train_target, dtype=np.uint8)
    train_data = train_data.reshape(train_data.shape[0], 1, img_rows, img_cols)
    # Convert to 0 or 1
    train_target = get_empty_mask_state(train_target)
    train_target = np_utils.to_categorical(train_target, 2)
    train_data = train_data.astype('float32')
    train_data /= 255
    print('Train shape:', train_data.shape)
    print(train_data.shape[0], 'train samples')
    return train_data, train_target, train_id


def read_and_normalize_test_data(img_rows, img_cols):
    test_data, test_id = load_test(img_rows, img_cols)
    test_data = np.array(test_data, dtype=np.uint8)
    test_data = test_data.reshape(test_data.shape[0], 1, img_rows, img_cols)
    test_data = test_data.astype('float32')
    test_data /= 255
    print('Test shape:', test_data.shape)
    print(test_data.shape[0], 'test samples')
    return test_data, test_id


def merge_several_folds_mean(data, nfolds):
    a = np.array(data[0])
    for i in range(1, nfolds):
        a += np.array(data[i])
    a /= nfolds
    return a.tolist()


def create_model(img_rows, img_cols):
    model = Sequential()
    model.add(Dropout(0.25, input_shape=(1, img_rows, img_cols)))

    model.add(Convolution2D(8, 3, 3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(Convolution2D(8, 3, 3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Convolution2D(16, 3, 3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(Convolution2D(16, 3, 3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Convolution2D(32, 3, 3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(Convolution2D(32, 3, 3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Convolution2D(64, 3, 3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, 3, 3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(2))
    model.add(Activation('softmax'))

    model.compile(optimizer=Adam(), loss='categorical_crossentropy')
    return model


def getPredScorePercent(train_target, train_id, predictions_valid):
    perc = 0
    for i in range(len(train_target)):
        pred = 1
        if predictions_valid[i][0] > 0.5:
            pred = 0
        real = 1
        if train_target[i][0] > 0.5:
            real = 0
        if real == pred:
            perc += 1
    perc /= len(train_target)
    return perc

# %%
train_data, train_target, train_id = read_and_normalize_train_data(img_rows, img_cols)
test_data, test_id = read_and_normalize_test_data(img_rows, img_cols)
# Out:
# Read train images
# Read train data time: 21.09 seconds
# Train shape: (5635, 1, 64, 64)
# 5635 train samples
# Read test images
# Read test data time: 14.5 seconds
# Test shape: (5508, 1, 64, 64)
# 5508 test samples

# %%
batch_size = 64
nb_epoch = 100

yfull_train = np.empty((train_data.shape[0], 2))
yfull_test = []
patient = np.fromiter(map(lambda s: int(s.split('_')[0]), train_id), dtype=np.int)

for i in range(5):
    model = create_model(img_rows, img_cols)
    sel = (patient >= i * 10) & (patient < (i + 1) * 10)
    X_train, X_valid = train_data[np.logical_not(sel)], train_data[sel]
    Y_train, Y_valid = train_target[np.logical_not(sel)], train_target[sel]

    print('Split train: ', len(X_train), len(Y_train))
    print('Split valid: ', len(X_valid), len(Y_valid))

    filepath = 'checkpoint' + str(i)
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=5, verbose=0),
        ModelCheckpoint(filepath, save_best_only=True)
    ]
    model.fit(X_train, Y_train, batch_size=batch_size, nb_epoch=nb_epoch,
          shuffle=True, verbose=1, validation_data=(X_valid, Y_valid),
          callbacks=callbacks)

    model.load_weights(filepath)

    predictions_valid = model.predict(X_valid, batch_size=batch_size, verbose=1)
    score = log_loss(Y_valid, predictions_valid)
    print('Score log_loss: ', score)

    yfull_train[sel] = predictions_valid

    # Store test predictions
    test_prediction = model.predict(test_data, batch_size=batch_size, verbose=1)
    yfull_test.append(test_prediction)
# Out:
# Split train:  4557 4557
# Split valid:  1078 1078
# Train on 4557 samples, validate on 1078 samples
# Epoch 1/100
# 2s - loss: 0.6752 - val_loss: 0.6806
# Epoch 2/100
# 2s - loss: 0.6382 - val_loss: 0.6630
# Epoch 3/100
# 2s - loss: 0.6174 - val_loss: 0.6483
# Epoch 4/100
# 2s - loss: 0.5737 - val_loss: 0.6467
# Epoch 5/100
# 2s - loss: 0.5533 - val_loss: 0.6422
# Epoch 6/100
# 2s - loss: 0.5299 - val_loss: 0.6465
# Epoch 7/100
# 2s - loss: 0.5205 - val_loss: 0.6411
# Epoch 8/100
# 2s - loss: 0.5126 - val_loss: 0.6480
# Epoch 9/100
# 2s - loss: 0.5083 - val_loss: 0.6420
# Epoch 10/100
# 2s - loss: 0.4948 - val_loss: 0.6339
# Epoch 11/100
# 2s - loss: 0.4912 - val_loss: 0.6502
# Epoch 12/100
# 2s - loss: 0.4838 - val_loss: 0.6489
# Epoch 13/100
# 2s - loss: 0.4741 - val_loss: 0.6477
# Epoch 14/100
# 2s - loss: 0.4791 - val_loss: 0.6443
# Epoch 15/100
# 2s - loss: 0.4701 - val_loss: 0.6496
# Epoch 16/100
# 2s - loss: 0.4615 - val_loss: 0.6431
# 1078/1078 [==============================] - 0s
# Score log_loss:  0.633892902747
# 5504/5508 [============================>.] - ETA: 0sSplit train:  4436 4436
# Split valid:  1199 1199
# Train on 4436 samples, validate on 1199 samples
# Epoch 1/100
# 2s - loss: 0.6669 - val_loss: 0.6874
# Epoch 2/100
# 2s - loss: 0.6222 - val_loss: 0.6770
# Epoch 3/100
# 2s - loss: 0.5903 - val_loss: 0.6797
# Epoch 4/100
# 2s - loss: 0.5710 - val_loss: 0.6726
# Epoch 5/100
# 2s - loss: 0.5425 - val_loss: 0.6736
# Epoch 6/100
# 2s - loss: 0.5191 - val_loss: 0.6683
# Epoch 7/100
# 2s - loss: 0.5153 - val_loss: 0.6763
# Epoch 8/100
# 2s - loss: 0.4925 - val_loss: 0.6731
# Epoch 9/100
# 2s - loss: 0.4928 - val_loss: 0.6718
# Epoch 10/100
# 2s - loss: 0.4761 - val_loss: 0.6788
# Epoch 11/100
# 2s - loss: 0.4738 - val_loss: 0.6779
# Epoch 12/100
# 2s - loss: 0.4650 - val_loss: 0.6639
# Epoch 13/100
# 2s - loss: 0.4639 - val_loss: 0.6684
# Epoch 14/100
# 2s - loss: 0.4583 - val_loss: 0.6719
# Epoch 15/100
# 2s - loss: 0.4539 - val_loss: 0.6731
# Epoch 16/100
# 2s - loss: 0.4478 - val_loss: 0.6724
# Epoch 17/100
# 2s - loss: 0.4391 - val_loss: 0.6737
# Epoch 18/100
# 2s - loss: 0.4405 - val_loss: 0.6780
# 1152/1199 [===========================>..] - ETA: 0sScore log_loss:  0.663875054709
# 5504/5508 [============================>.] - ETA: 0sSplit train:  4435 4435
# Split valid:  1200 1200
# Train on 4435 samples, validate on 1200 samples
# Epoch 1/100
# 2s - loss: 0.6789 - val_loss: 0.6837
# Epoch 2/100
# 2s - loss: 0.6138 - val_loss: 0.6781
# Epoch 3/100
# 2s - loss: 0.5808 - val_loss: 0.6757
# Epoch 4/100
# 2s - loss: 0.5638 - val_loss: 0.6754
# Epoch 5/100
# 2s - loss: 0.5399 - val_loss: 0.6704
# Epoch 6/100
# 2s - loss: 0.5176 - val_loss: 0.6728
# Epoch 7/100
# 2s - loss: 0.5173 - val_loss: 0.6750
# Epoch 8/100
# 2s - loss: 0.5047 - val_loss: 0.6680
# Epoch 9/100
# 2s - loss: 0.4941 - val_loss: 0.6627
# Epoch 10/100
# 2s - loss: 0.4851 - val_loss: 0.6740
# Epoch 11/100
# 2s - loss: 0.4749 - val_loss: 0.6742
# Epoch 12/100
# 2s - loss: 0.4691 - val_loss: 0.6743
# Epoch 13/100
# 2s - loss: 0.4715 - val_loss: 0.6871
# Epoch 14/100
# 2s - loss: 0.4643 - val_loss: 0.6752
# Epoch 15/100
# 2s - loss: 0.4561 - val_loss: 0.6805
# 1152/1200 [===========================>..] - ETA: 0sScore log_loss:  0.662683764448
# 5504/5508 [============================>.] - ETA: 0sSplit train:  4436 4436
# Split valid:  1199 1199
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3dd3fbd6e018> in <module>()
#      22     model.fit(X_train, Y_train, batch_size=batch_size, nb_epoch=nb_epoch,
#      23           shuffle=True, verbose=2, validation_data=(X_valid, Y_valid),
# ---> 24           callbacks=callbacks)
#      25
#      26     model.load_weights(filepath)
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/keras/models.py in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, **kwargs)
#     406                               shuffle=shuffle,
#     407                               class_weight=class_weight,
# --> 408                               sample_weight=sample_weight)
#     409
#     410     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight)
#    1036         else:
#    1037             ins = x + y + sample_weights
# -> 1038         self._make_train_function()
#    1039         f = self.train_function
#    1040
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/keras/engine/training.py in _make_train_function(self)
#     669                                              [self.total_loss] + self.metrics,
#     670                                              updates=updates,
# --> 671                                              **self._function_kwargs)
#     672
#     673     def _make_test_function(self):
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/keras/backend/theano_backend.py in function(inputs, outputs, updates, **kwargs)
#     526                 msg = "Invalid argument '%s' passed to K.function" % key
#     527                 raise ValueError(msg)
# --> 528     return Function(inputs, outputs, updates=updates, **kwargs)
#     529
#     530
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/keras/backend/theano_backend.py in __init__(self, inputs, outputs, updates, **kwargs)
#     512                                         allow_input_downcast=True,
#     513                                         on_unused_input='warn',
# --> 514                                         **kwargs)
#     515
#     516     def __call__(self, inputs):
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/theano/compile/function.py in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     318                    on_unused_input=on_unused_input,
#     319                    profile=profile,
# --> 320                    output_keys=output_keys)
#     321     # We need to add the flag check_aliased inputs if we have any mutable or
#     322     # borrowed used defined inputs
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/theano/compile/pfunc.py in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     477                          accept_inplace=accept_inplace, name=name,
#     478                          profile=profile, on_unused_input=on_unused_input,
# --> 479                          output_keys=output_keys)
#     480
#     481
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/theano/compile/function_module.py in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1774                    profile=profile,
#    1775                    on_unused_input=on_unused_input,
# -> 1776                    output_keys=output_keys).create(
#    1777             defaults)
#    1778
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/theano/compile/function_module.py in __init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input, fgraph, output_keys)
#    1454                         optimizer, inputs, outputs)
#    1455                 else:
# -> 1456                     optimizer_profile = optimizer(fgraph)
#    1457
#    1458                 end_optimizer = time.time()
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/theano/gof/opt.py in __call__(self, fgraph)
#      99
#     100         """
# --> 101         return self.optimize(fgraph)
#     102
#     103     def add_requirements(self, fgraph):
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/theano/gof/opt.py in optimize(self, fgraph, *args, **kwargs)
#      87             orig = theano.tensor.basic.constant.enable
#      88             theano.tensor.basic.constant.enable = False
# ---> 89             ret = self.apply(fgraph, *args, **kwargs)
#      90         finally:
#      91             theano.tensor.basic.constant.enable = orig
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/theano/gof/opt.py in apply(self, fgraph)
#     228             try:
#     229                 t0 = time.time()
# --> 230                 sub_prof = optimizer.optimize(fgraph)
#     231                 l.append(float(time.time() - t0))
#     232                 sub_profs.append(sub_prof)
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/theano/gof/opt.py in optimize(self, fgraph, *args, **kwargs)
#      87             orig = theano.tensor.basic.constant.enable
#      88             theano.tensor.basic.constant.enable = False
# ---> 89             ret = self.apply(fgraph, *args, **kwargs)
#      90         finally:
#      91             theano.tensor.basic.constant.enable = orig
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/theano/tensor/opt.py in inplace_elemwise_optimizer(fgraph)
#     394                         nb_change_no_validate += 1
#     395                         if nb_change_no_validate >= check_each_change:
# --> 396                             fgraph.validate()
#     397                             chk = fgraph.checkpoint()
#     398                             nb_change_no_validate = 0
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/theano/gof/toolbox.py in validate_(self, fgraph)
#     230         t0 = time.time()
#     231         try:
# --> 232             ret = fgraph.execute_callbacks('validate')
#     233         except Exception as e:
#     234             cf = inspect.currentframe()
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/theano/gof/fg.py in execute_callbacks(self, name, *args, **kwargs)
#     671                 continue
#     672             tf0 = time.time()
# --> 673             fn(self, *args, **kwargs)
#     674             self.execute_callbacks_times[feature] += time.time() - tf0
#     675         self.execute_callbacks_time += time.time() - t0
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/theano/gof/destroyhandler.py in validate(self, fgraph)
#     902         """
#     903         if self.destroyers:
# --> 904             ords = self.orderings(fgraph)
#     905
#     906             if _contains_cycle(fgraph, ords):
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/theano/gof/destroyhandler.py in orderings(self, fgraph)
#    1014                     # add the rule: app must be preceded by all other Apply instances that
#    1015                     # depend on destroyed_input
# -> 1016                     root_clients = OrderedSet()
#    1017                     for r in root_impact:
#    1018                         assert not [a for a, c in self.clients[r].items() if not c]
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/theano/misc/ordered_set.py in __init__(self, iterable)
#      89         check_deterministic(iterable)
#      90         self.__root = root = Link()         # sentinel node for doubly linked list
# ---> 91         root.prev = root.next = weakref.ref(root)
#      92         self.__map = {}                     # key --> link
#      93         if iterable is not None:
#
# KeyboardInterrupt:

# %%
score = log_loss(train_target, yfull_train)
print("Log_loss train independent avg: ", score)

print('Final log_loss: {}, rows: {} cols: {} nfolds: {} epoch: {}'.format(score, img_rows, img_cols, nfolds, nb_epoch))
perc = getPredScorePercent(train_target, train_id, yfull_train)
print('Percent success: {}'.format(perc))

info_string = 'loss_' + str(score) \
                + '_r_' + str(img_rows) \
                + '_c_' + str(img_cols) \
                + '_folds_' + str(nfolds) \
                + '_ep_' + str(nb_epoch)

test_res = merge_several_folds_mean(yfull_test, nfolds)
print(test_res)
print(test_id)
create_submission(test_res, test_id, info_string)
