# %%
import numpy as np
import pandas as pd

# %%
sub = pd.read_csv('rf_submission_2016-06-08-18-32.csv')

# %%
sub.drop(['x', 'y'], axis = 1).to_csv('rf_fin_submission_2016-06-08-18-32.csv',index=False)

# %%
pd.read_csv('rf_fin_submission_2016-06-08-18-32.csv')
# Out:
#           row_id                          place_id
# 0              0  4393146716 5658334585 3330035982
# 1              1  2465239230 6688493189 9801651394
# 2              2  2516481553 7610291205 1843269742
# 3              3  7995458948 8393706174 4628671813
# 4              4  3661789744 4791791829 4764406629
# 5              5  8370753254 9973067176 3969374613
# 6              6  8079431713 1107445120 1907317696
# 7              7  4346049470 1792131971 5467395648
# 8              8  6470278079 6421756522 4739087577
# 9              9  8837567760 5760938807 2193101183
# 10            10  2852012701 9761868933 4586965148
# 11            11  9349368505 6227635771 2151183494
# 12            12  9031150064 6291666280 9999916757
# 13            13  2434531540 9388356666 5313553144
# 14            14  3756584599 7405695170 3515136371
# 15            15  4390687315 8442351461 3851236965
# 16            16  9440230828 4198289417 1992902646
# ...
